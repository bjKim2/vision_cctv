# %%
using Flux
using Flux.Data: DataLoader

# %%
using Pkg
ENV["PYTHON"] = "/home/tekim/haha/bin/python3.9"
Pkg.build("PyCall")
using PyCall
# Out:
#     Building Conda ─→ `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/6e47d11ea2776bc5627421d59cdcc1296c058071/build.log`
#     Building PyCall → `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/53b8b07b721b77144a0fbbbc2675222ebf40a02d/build.log`

# %%
import Pkg; Pkg.add("Images")
# Out:
#     Updating registry at `~/.julia/registries/General`
#     Updating git-repo `https://github.com/JuliaRegistries/General.git`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.8/Project.toml`
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`

# %%
@pyimport glob

a = glob.glob("/mnt/ssd2/tekim/datasets/roboflow_vest/merge/test/images/*")
print(typeof(a))
print(length(a))
# Out:
# Vector{
# String}147

# %%
using Images

# %%
imgs = Array{Float64}([1,2,3,4])
# Out:
# 4-element Vector{Float64}:
#  1.0
#  2.0
#  3.0
#  4.0

# %%
test = zeros(Float32 , 2,2,2)
test[1,1,1] = 0
test[2,1,1] = 4
test[1,2,1] = 2
test[2,2,1] = 6
test[1,1,2] = 1
test[2,1,2] = 5
test[1,2,2] = 3
test[2,2,2] = 7

count = 0
# print(count)

for x in test[:,1,1]
    count +=1
    println(x)
end
# Out:
# 0.0
# 4.0

# %%
println(test[:])
println(test)
println(typeof(test[:]))
println(typeof(test))
# Out:
# Float32[0.0, 4.0, 2.0, 6.0, 1.0, 5.0, 3.0, 7.0]
# [0.0 2.0; 4.0 6.0;;; 1.0 3.0; 5.0 7.0]
# Vector{Float32}
# Array{Float32, 3}

# %%
for x in 1:length(test[:,1,1,1,1,1,1])
    println(test[x,:,:])
end
# Out:
# Float32[0.0 1.0; 2.0 3.0]
# Float32[4.0 5.0; 6.0 7.0]

# %%
typeof(reshape(test, 8,1))
# Out:
# Matrix{Float32} (alias for Array{Float32, 2})

# %%
Float64(2)
# Out:
# 2.0

# %%
test[3]
# Out:
# Float32

# %%
print("ahsdfuhas")
# Out:
# ahsdfuhas

# %%
length(test)
# Out:
# 8

# %%
imgs = zeros(Float32, length(a),416,416,3)
for x in 1:length(imgs[:,1,1,1])
    print(size(imgs[x,:,:,:]))
end
# Out:
# (416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)
# (416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)(416, 416, 3)
# ...

# %%
# Out:
# MethodError: no method matching setindex!(::Type{Array{Float64}}, ::Int64, ::Int64, ::Int64, ::Int64, ::Int64)
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/vision_cctv/julia/data.ipynb:1

# %%
size(imgs)
# Out:
# MethodError: no method matching size(::Type{Array{Float64}})
#
# Closest candidates are:
#
#   size(!Matched::Union{LinearAlgebra.QR, LinearAlgebra.QRCompactWY, LinearAlgebra.QRPivoted}) at ~/julia-1.8.2/share/julia/stdlib/v1.8/LinearAlgebra/src/qr.jl:581
#
#   size(!Matched::Union{LinearAlgebra.QR, LinearAlgebra.QRCompactWY, LinearAlgebra.QRPivoted}, !Matched::Integer) at ~/julia-1.8.2/share/julia/stdlib/v1.8/LinearAlgebra/src/qr.jl:580
#
#   size(!Matched::Union{LinearAlgebra.Cholesky, LinearAlgebra.CholeskyPivoted}) at ~/julia-1.8.2/share/julia/stdlib/v1.8/LinearAlgebra/src/cholesky.jl:514
#
#   ...
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/vision_cctv/julia/data.ipynb:1

# %%
imgs = 
for img_file in a
    img = load(img_file)
    temp = channelview(img)
    temp = convert(Array{Float64},temp)

# %%
img = load(a[1])
# Out:
# 416×416 Array{RGB{N0f8},2} with eltype RGB{N0f8}:
#  RGB{N0f8}(0.216,0.216,0.216)  …  RGB{N0f8}(0.204,0.204,0.204)
#  RGB{N0f8}(0.243,0.243,0.243)     RGB{N0f8}(0.243,0.243,0.243)
#  RGB{N0f8}(0.2,0.2,0.2)           RGB{N0f8}(0.22,0.22,0.22)
#  RGB{N0f8}(0.227,0.227,0.227)     RGB{N0f8}(0.235,0.235,0.235)
#  RGB{N0f8}(0.145,0.145,0.145)     RGB{N0f8}(0.235,0.235,0.235)
#  RGB{N0f8}(0.227,0.227,0.227)  …  RGB{N0f8}(0.216,0.216,0.216)
#  RGB{N0f8}(0.231,0.231,0.231)     RGB{N0f8}(0.231,0.231,0.231)
#  RGB{N0f8}(0.212,0.212,0.212)     RGB{N0f8}(0.18,0.18,0.18)
#  RGB{N0f8}(0.22,0.22,0.22)        RGB{N0f8}(0.239,0.239,0.239)
#  RGB{N0f8}(0.22,0.22,0.22)        RGB{N0f8}(0.212,0.212,0.212)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.22,0.22,0.22)        RGB{N0f8}(0.216,0.216,0.216)
#  RGB{N0f8}(0.2,0.2,0.2)           RGB{N0f8}(0.22,0.22,0.22)
#  RGB{N0f8}(0.263,0.263,0.263)     RGB{N0f8}(0.22,0.22,0.22)
#  RGB{N0f8}(0.184,0.184,0.184)  …  RGB{N0f8}(0.22,0.22,0.22)
# ...

# %%
temp = channelview(img)
temp = convert(Array{Float64},temp)
# Out:
# 3×416×416 Array{Float64, 3}:
# [:, :, 1] =
#  0.215686  0.243137  0.2  0.227451  0.145098  …  0.156863  0.247059  0.192157
#  0.215686  0.243137  0.2  0.227451  0.145098     0.156863  0.247059  0.192157
#  0.215686  0.243137  0.2  0.227451  0.145098     0.156863  0.247059  0.192157
#
# [:, :, 2] =
#  0.243137  0.145098  0.278431  0.188235  …  0.27451  0.239216  0.184314
#  0.243137  0.145098  0.278431  0.188235     0.27451  0.239216  0.184314
#  0.243137  0.145098  0.278431  0.188235     0.27451  0.239216  0.184314
#
# [:, :, 3] =
#  0.223529  0.203922  0.219608  0.219608  …  0.168627  0.172549  0.27451
#  0.223529  0.203922  0.219608  0.219608     0.168627  0.172549  0.27451
#  0.223529  0.203922  0.219608  0.219608     0.168627  0.172549  0.27451
#
# ;;; …
#
# [:, :, 414] =
#  0.172549  0.223529  0.215686  0.239216  …  0.219608  0.219608  0.219608
#  0.172549  0.223529  0.215686  0.239216     0.219608  0.219608  0.219608
# ...

# %%
typeof(red2)
# Out:
# Matrix{N0f8} (alias for Array{Normed{UInt8, 8}, 2})

# %%
m = convert(Array{Float64},gray_img)
typeof(m)
typeof(gray_img)
colorview(Gray,green2)
# Out:
# 416×416 reinterpret(reshape, Gray{N0f8}, ::Array{N0f8,2}) with eltype Gray{N0f8}:
#  Gray{N0f8}(0.216)  Gray{N0f8}(0.243)  …  Gray{N0f8}(0.204)
#  Gray{N0f8}(0.243)  Gray{N0f8}(0.145)     Gray{N0f8}(0.243)
#  Gray{N0f8}(0.2)    Gray{N0f8}(0.278)     Gray{N0f8}(0.22)
#  Gray{N0f8}(0.227)  Gray{N0f8}(0.188)     Gray{N0f8}(0.235)
#  Gray{N0f8}(0.145)  Gray{N0f8}(0.31)      Gray{N0f8}(0.235)
#  Gray{N0f8}(0.227)  Gray{N0f8}(0.247)  …  Gray{N0f8}(0.216)
#  Gray{N0f8}(0.231)  Gray{N0f8}(0.149)     Gray{N0f8}(0.231)
#  Gray{N0f8}(0.212)  Gray{N0f8}(0.286)     Gray{N0f8}(0.18)
#  Gray{N0f8}(0.22)   Gray{N0f8}(0.22)      Gray{N0f8}(0.239)
#  Gray{N0f8}(0.22)   Gray{N0f8}(0.22)      Gray{N0f8}(0.212)
#  ⋮                                     ⋱  ⋮
#  Gray{N0f8}(0.22)   Gray{N0f8}(0.22)      Gray{N0f8}(0.216)
#  Gray{N0f8}(0.2)    Gray{N0f8}(0.208)     Gray{N0f8}(0.22)
#  Gray{N0f8}(0.263)  Gray{N0f8}(0.22)      Gray{N0f8}(0.22)
#  Gray{N0f8}(0.184)  Gray{N0f8}(0.176)  …  Gray{N0f8}(0.22)
# ...

# %%
colorview(Gray,blue2)
# Out:
# 416×416 reinterpret(reshape, Gray{N0f8}, ::Array{N0f8,2}) with eltype Gray{N0f8}:
#  Gray{N0f8}(0.216)  Gray{N0f8}(0.243)  …  Gray{N0f8}(0.204)
#  Gray{N0f8}(0.243)  Gray{N0f8}(0.145)     Gray{N0f8}(0.243)
#  Gray{N0f8}(0.2)    Gray{N0f8}(0.278)     Gray{N0f8}(0.22)
#  Gray{N0f8}(0.227)  Gray{N0f8}(0.188)     Gray{N0f8}(0.235)
#  Gray{N0f8}(0.145)  Gray{N0f8}(0.31)      Gray{N0f8}(0.235)
#  Gray{N0f8}(0.227)  Gray{N0f8}(0.247)  …  Gray{N0f8}(0.216)
#  Gray{N0f8}(0.231)  Gray{N0f8}(0.149)     Gray{N0f8}(0.231)
#  Gray{N0f8}(0.212)  Gray{N0f8}(0.286)     Gray{N0f8}(0.18)
#  Gray{N0f8}(0.22)   Gray{N0f8}(0.22)      Gray{N0f8}(0.239)
#  Gray{N0f8}(0.22)   Gray{N0f8}(0.22)      Gray{N0f8}(0.212)
#  ⋮                                     ⋱  ⋮
#  Gray{N0f8}(0.22)   Gray{N0f8}(0.22)      Gray{N0f8}(0.216)
#  Gray{N0f8}(0.2)    Gray{N0f8}(0.208)     Gray{N0f8}(0.22)
#  Gray{N0f8}(0.263)  Gray{N0f8}(0.22)      Gray{N0f8}(0.22)
#  Gray{N0f8}(0.184)  Gray{N0f8}(0.176)  …  Gray{N0f8}(0.22)
# ...

# %%
img2 = copy(img)
# Out:
# 416×416 Array{RGB{N0f8},2} with eltype RGB{N0f8}:
#  RGB{N0f8}(0.216,0.216,0.216)  …  RGB{N0f8}(0.204,0.204,0.204)
#  RGB{N0f8}(0.243,0.243,0.243)     RGB{N0f8}(0.243,0.243,0.243)
#  RGB{N0f8}(0.2,0.2,0.2)           RGB{N0f8}(0.22,0.22,0.22)
#  RGB{N0f8}(0.227,0.227,0.227)     RGB{N0f8}(0.235,0.235,0.235)
#  RGB{N0f8}(0.145,0.145,0.145)     RGB{N0f8}(0.235,0.235,0.235)
#  RGB{N0f8}(0.227,0.227,0.227)  …  RGB{N0f8}(0.216,0.216,0.216)
#  RGB{N0f8}(0.231,0.231,0.231)     RGB{N0f8}(0.231,0.231,0.231)
#  RGB{N0f8}(0.212,0.212,0.212)     RGB{N0f8}(0.18,0.18,0.18)
#  RGB{N0f8}(0.22,0.22,0.22)        RGB{N0f8}(0.239,0.239,0.239)
#  RGB{N0f8}(0.22,0.22,0.22)        RGB{N0f8}(0.212,0.212,0.212)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.22,0.22,0.22)        RGB{N0f8}(0.216,0.216,0.216)
#  RGB{N0f8}(0.2,0.2,0.2)           RGB{N0f8}(0.22,0.22,0.22)
#  RGB{N0f8}(0.263,0.263,0.263)     RGB{N0f8}(0.22,0.22,0.22)
#  RGB{N0f8}(0.184,0.184,0.184)  …  RGB{N0f8}(0.22,0.22,0.22)
# ...

# %%
img2 = convert(Array{Float64},img)
# Out:
# MethodError: Cannot `convert` an object of type RGB{N0f8} to an object of type Float64
#
# Closest candidates are:
#
#   convert(::Type{T}, !Matched::Gray24) where T<:Real at ~/.julia/packages/ColorTypes/1dGw6/src/conversions.jl:114
#
#   convert(::Type{T}, !Matched::Gray) where T<:Real at ~/.julia/packages/ColorTypes/1dGw6/src/conversions.jl:113
#
#   convert(::Type{T}, !Matched::LLVM.GenericValue, !Matched::LLVM.LLVMType) where T<:AbstractFloat at ~/.julia/packages/LLVM/WjSQG/src/execution.jl:39
#
#   ...
#
#
#
# Stacktrace:
#
#   [1] setindex!(A::Matrix{Float64}, x::RGB{N0f8}, i1::Int64)
#
#     @ Base ./array.jl:966
#
#   [2] _unsafe_copyto!(dest::Matrix{Float64}, doffs::Int64, src::Matrix{RGB{N0f8}}, soffs::Int64, n::Int64)
#
#     @ Base ./array.jl:253
#
#   [3] unsafe_copyto!
#
#     @ ./array.jl:307 [inlined]
#
#   [4] _copyto_impl!
#
#     @ ./array.jl:331 [inlined]
#
#   [5] copyto!
#
#     @ ./array.jl:317 [inlined]
#
#   [6] copyto!
#
#     @ ./array.jl:343 [inlined]
#
# ...

# %%
import YAML

# %%
using Images
# Out:
# ArgumentError: Package Image not found in current path.
#
# - Run `import Pkg; Pkg.add("Image")` to install the Image package.
#
#
#
# Stacktrace:
#
#   [1] macro expansion
#
#     @ ./loading.jl:1163 [inlined]
#
#   [2] macro expansion
#
#     @ ./lock.jl:223 [inlined]
#
#   [3] require(into::Module, mod::Symbol)
#
#     @ Base ./loading.jl:1144
#
#   [4] eval
#
#     @ ./boot.jl:368 [inlined]
#
#   [5] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#
#     @ Base ./loading.jl:1428
#
#   [6] #invokelatest#2
#
#     @ ./essentials.jl:729 [inlined]
#
#   [7] invokelatest
#
#     @ ./essentials.jl:726 [inlined]
#
#   [8] (::VSCodeServer.var"#198#199"{VSCodeServer.NotebookRunCellArguments, String})()
#
#     @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.38.2/scripts/packages/VSCodeServer/src/serve_notebook.jl:19
#
#   [9] withpath(f::VSCodeServer.var"#198#199"{VSCodeServer.NotebookRunCellArguments, String}, path::String)
#
# ...

# %%
yolov7_yaml = YAML.load_file("/mnt/ssd2/tekim/temp/yolov7/cfg/training/yolov7.yaml")
# Out:
# Dict{Any, Any} with 6 entries:
#   "anchors"        => [[12, 16, 19, 36, 40, 28], [36, 75, 76, 55, 72, 146], [14…
#   "head"           => Vector{Any}[[-1, 1, "SPPCSPC", [512]], [-1, 1, "Conv", [2…
#   "nc"             => 80
#   "depth_multiple" => 1.0
#   "backbone"       => Vector{Any}[[-1, 1, "Conv", [32, 3, 1]], [-1, 1, "Conv", …
#   "width_multiple" => 1.0

# %%
count = 0
for i in [yolov7_yaml["backbone"]; yolov7_yaml["head"]]
    
    f, n, m, args = i[1], i[2], i[3], i[4]
    count += 1
    println(count, m)


    
end
# Out:
# 1Conv
# 2Conv
# 3Conv
# 4Conv
# 5Conv
# 6Conv
# 7Conv
# 8Conv
# 9Conv
# 10Conv
# 11Concat
# 12Conv
# 13MP
# 14Conv
# 15Conv
# 16Conv
# 17Concat
# 18Conv
# 19Conv
# 20Conv
# 21Conv
# 22Conv
# 23Conv
# 24Concat
# 25Conv
# 26MP
# 27Conv
# 28Conv
# 29Conv
# 30Concat
# 31Conv
# 32Conv
# 33Conv
# 34Conv
# 35Conv
# 36Conv
# 37Concat
# 38Conv
# 39MP
# 40Conv
# 41Conv
# 42Conv
# 43Concat
# 44Conv
# 45Conv
# 46Conv
# 47Conv
# 48Conv
# 49Conv
# 50Concat
# 51Conv
# 52SPPCSPC
# 53Conv
# 54nn.Upsample
# 55Conv
# 56Concat
# 57Conv
# 58Conv
# 59Conv
# 60Conv
# 61Conv
# 62Conv
# 63Concat
# 64Conv
# 65Conv
# 66nn.Upsample
# 67Conv
# 68Concat
# 69Conv
# 70Conv
# 71Conv
# 72Conv
# 73Conv
# 74Conv
# 75Concat
# 76Conv
# 77MP
# 78Conv
# 79Conv
# 80Conv
# 81Concat
# 82Conv
# 83Conv
# 84Conv
# 85Conv
# 86Conv
# 87Conv
# 88Concat
# 89Conv
# 90MP
# 91Conv
# 92Conv
# 93Conv
# 94Concat
# 95Conv
# 96Conv
# 97Conv
# 98Conv
# 99Conv
# 100Conv
# 101Concat
# 102Conv
# 103RepConv
# 104RepConv
# 105RepConv
# ...

# %%
print(typeof((5,5)))
# Out:
# Tuple{Int64, Int64}

# %%
modela = Chain(
    Conv((5, 5), 2*2=>16, relu)
)
modelb = Chain(
    Conv((5, 5), 2*2=>16, relu)
)
modelc = Chain(
    modela,modelb
)
modelc
# Out:
# Chain(
#   Chain(
#     Conv((5, 5), 4 => 16, relu),        # 1_616 parameters
#   ),
#   Chain(
#     Conv((5, 5), 4 => 16, relu),        # 1_616 parameters
#   ),
# )                   # Total: 4 arrays, 3_232 parameters, 13.672 KiB.

# %%
eval("a = 2 print(a)")
# Out:
# "a = 2 print(a)"

# %%
py"""
import numpy as np
import torch

def sinpi(x):
    return np.sin(np.pi * x)
"""

a = py"torch.tensor([3,2,1])"
b = py"torch.nn.Sequential()"
@pyimport torch
c = torch.nn.Sequential(
    torch.nn.Linear(1,10),
    torch.nn.Linear(10,20)
)
print(typeof(c))
print(c)

print(typeof(b))

print(typeof(a))
# print([3,2,1])
# Out:
# PyObjectPyObject Sequential(
#   (0): Linear(in_features=1, out_features=10, bias=True)
#   (1): Linear(in_features=10, out_features=20, bias=True)
# )PyObjectPyObject

# %%
a = 1
@pyimport numpy as np
@pyimport torch
@pyimport tensorflow as tf
py"import torch"
# py"torch.tensor([1,2,3])"

# a = py"torch.tensor([3,2,1])"
println(torch.tensor([1,2,3]))
println(torch.tensor([1,2,3]))

println(np.array([1,2,3]))
println(typeof(np.array([2,3])))
# py""
a = py"2"
println(a)
b = [1,2,3]
print(typeof(b))
# Out:
# PyError ($(Expr(:escape, :(ccall(#= /home/tekim/.julia/packages/PyCall/ygXW2/src/pyeval.jl:34 =# @pysym(:Py_CompileString), PyPtr, (Cstring, Cstring, Cint), s, fname, input_type))))) <class 'SyntaxError'>
#
# SyntaxError('invalid syntax', ('/home/tekim/.julia/packages/PyCall/ygXW2/src/pyeval.jl', 1, 1, 'import torch'))
#
#
#
#
#
# Stacktrace:
#
#  [1] pyerr_check
#
#    @ ~/.julia/packages/PyCall/ygXW2/src/exception.jl:62 [inlined]
#
#  [2] pyerr_check
#
#    @ ~/.julia/packages/PyCall/ygXW2/src/exception.jl:66 [inlined]
#
#  [3] _handle_error(msg::String)
#
#    @ PyCall ~/.julia/packages/PyCall/ygXW2/src/exception.jl:83
#
#  [4] macro expansion
#
#    @ ~/.julia/packages/PyCall/ygXW2/src/exception.jl:97 [inlined]
#
#  [5] pyeval_(s::String, globals::PyDict{String, PyObject, true}, locals::PyDict{String, PyObject, true}, input_type::Int64, fname::String)
#
#    @ PyCall ~/.julia/packages/PyCall/ygXW2/src/pyeval.jl:34
#
#  [6] top-level scope
#
# ...

# %%
for i in yolov7_yaml["head"]
    println(i, length(i))
end
# Out:
# Any[-1, 1, "SPPCSPC", [512]]4
# Any[-1, 1, "Conv", [256, 1, 1]]4
# Any[-1, 1, "nn.Upsample", Any["None", 2, "nearest"]]4
# Any[37, 1, "Conv", [256, 1, 1]]4
# Any[[-1, -2], 1, "Concat", [1]]4
# Any[-1, 1, "Conv", [256, 1, 1]]4
# Any[-2, 1, "Conv", [256, 1, 1]]4
# Any[-1, 1, "Conv", [128, 3, 1]]4
# Any[-1, 1, "Conv", [128, 3, 1]]4
# Any[-1, 1, "Conv", [128, 3, 1]]4
# Any[-1, 1, "Conv", [128, 3, 1]]4
# Any[[-1, -2, -3, -4, -5, -6], 1, "Concat", [1]]4
# Any[-1, 1, "Conv", [256, 1, 1]]4
# Any[-1, 1, "Conv", [128, 1, 1]]4
# Any[-1, 1, "nn.Upsample", Any["None", 2, "nearest"]]4
# Any[24, 1, "Conv", [128, 1, 1]]4
# Any[[-1, -2], 1, "Concat", [1]]4
# Any[-1, 1, "Conv", [128, 1, 1]]4
# Any[-2, 1, "Conv", [128, 1, 1]]4
# Any[-1, 1, "Conv", [64, 3, 1]]4
# Any[-1, 1, "Conv", [64, 3, 1]]4
# Any[-1, 1, "Conv", [64, 3, 1]]4
# Any[-1, 1, "Conv", [64, 3, 1]]4
# Any[[-1, -2, -3, -4, -5, -6], 1, "Concat", [1]]4
# Any[-1, 1, "Conv", [128, 1, 1]]4
# Any[-1, 1, "MP", Any[]]4
# ...

# %%
Pkg.add(url="git://github.com/maxruby/OpenCV.jl.git")
using OpenCV
# Out:
#      Cloning git-repo `git://github.com/maxruby/OpenCV.jl.git`
# failed to clone from git://github.com/maxruby/OpenCV.jl.git, error: GitError(Code:ERROR, Class:OS, failed to connect to github.com: Connection timed out)
#
#
#
# Stacktrace:
#
#   [1] pkgerror(msg::String)
#
#     @ Pkg.Types ~/julia-1.8.2/share/julia/stdlib/v1.8/Pkg/src/Types.jl:67
#
#   [2] clone(io::VSCodeServer.IJuliaCore.IJuliaStdio{Base.PipeEndpoint, typeof(VSCodeServer.io_send_callback)}, url::String, source_path::String; header::Nothing, credentials::Nothing, kwargs::Base.Pairs{Symbol, Bool, Tuple{Symbol}, NamedTuple{(:isbare,), Tuple{Bool}}})
#
#     @ Pkg.GitTools ~/julia-1.8.2/share/julia/stdlib/v1.8/Pkg/src/GitTools.jl:126
#
#   [3] #ensure_clone#2
#
#     @ ~/julia-1.8.2/share/julia/stdlib/v1.8/Pkg/src/GitTools.jl:74 [inlined]
#
#   [4] handle_repo_add!(ctx::Pkg.Types.Context, pkg::Pkg.Types.PackageSpec)
#
#     @ Pkg.Types ~/julia-1.8.2/share/julia/stdlib/v1.8/Pkg/src/Types.jl:702
#
# ...
