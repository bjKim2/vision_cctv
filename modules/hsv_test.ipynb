# %%
import cv2
import numpy as np
from glob import glob
import matplotlib.pyplot as plt

# %%
imgs = glob('../../datasets/aihub_safety/val/*/*.jpg')

# %%
imgs[:10]
# Out:
# ['../../datasets/aihub_safety/val/[원천]2.공연장_부산 오페라 하우스 신축공사/S2-O1301M00257.jpg',
#  '../../datasets/aihub_safety/val/[원천]2.공연장_부산 오페라 하우스 신축공사/S2-O1301M102859.jpg',
#  '../../datasets/aihub_safety/val/[원천]2.공연장_부산 오페라 하우스 신축공사/S2-O1302M00358.jpg',
#  '../../datasets/aihub_safety/val/[원천]2.공연장_부산 오페라 하우스 신축공사/S2-O1301M00380.jpg',
#  '../../datasets/aihub_safety/val/[원천]2.공연장_부산 오페라 하우스 신축공사/S2-O1302M100350.jpg',
#  '../../datasets/aihub_safety/val/[원천]2.공연장_부산 오페라 하우스 신축공사/S2-O1301M01531.jpg',
#  '../../datasets/aihub_safety/val/[원천]2.공연장_부산 오페라 하우스 신축공사/S2-O1301M104514.jpg',
#  '../../datasets/aihub_safety/val/[원천]2.공연장_부산 오페라 하우스 신축공사/S2-O1301M102802.jpg',
#  '../../datasets/aihub_safety/val/[원천]2.공연장_부산 오페라 하우스 신축공사/S2-O1301M03976.jpg',
#  '../../datasets/aihub_safety/val/[원천]2.공연장_부산 오페라 하우스 신축공사/S2-O1302M100604.jpg']

# %%
img = cv2.imread(imgs[6])
img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.imshow(img_hsv[:,:,2],cmap='gray')

plt.show()

# %%
plt.imshow(img[...,::-1])

# %%
(img_gray == img_hsv[:,:,2]).sum()
# Out:
# 15907

# %%
img_gray.shape
# Out:
# (720, 1280)

# %%
1280*720
# Out:
# 921600

# %%
img_gray.max()
# Out:
# 238

# %%
plt.imshow(img_gray,cmap='gray')

# %%
plt.imshow(img[...,::-1])
